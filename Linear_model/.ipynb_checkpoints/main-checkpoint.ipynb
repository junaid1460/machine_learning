# %%
import pandas as pd
import tensorflow as tf
import io
import requests

# %% [markdown]
# # read data and fix errors
# the data read has some minor errors like string 'false' instead of boolean False
# let's fix them

# %%
#read training data set

def read_train_data():
    return pd.read_csv('./train.csv')
# normalize column values
def fix_errors(data):
    data['disable_communication'] = data['disable_communication'].replace(['false'],False)
    data['disable_communication'] = data['disable_communication'].replace(['true'],True)
    print('replaced \'false\' with False and \'true\' with True') 
    return data

# %%
#exchange rates from yahoo

def read_exchange_rates_json():
    url = 'https://finance.yahoo.com/webservice/v1/symbols/allcurrencies/quote?format=json'
    try:
        return pd.read_json(io.StringIO(requests.get(url).content.decode('utf-8')))['list']['resources']
    except:
        print('couldn\'t fetch data from yahoo, loading local data')
        return pd.read_json('./currencyrates.json')['list']['resources']
        

# make dictionary of required field
def get_exchange_rates_dataframe(data):
    rates = []
    for rate in data:
        dt = rate['resource']['fields']
        name = dt['name']
        if(name[0:3]!='USD'):
            continue
            
        if(len(name) < 6):
            rates = rates + [{'to':name,'price' : float(dt['price'])  }]
            continue
            
        _from,_to = name.split('/')
        rates = rates + [{'to':_to,'price' : float(dt['price'])  }]
    
    return pd.DataFrame.from_records(rates)

def get_price(code,data):
    return data[data.to == code ].price
# data frame from dictionary list

# %% [markdown]
# # data normalization
# the goal price is represented using many currencies. we convert all the currrency to US Dollars by grabbing exchange rate from Yahoo and diving all currencies  by it's exhange rate.

# %%
def normalize_price(data,ex_data):
    for index,dt in data.iterrows():
        price = float(dt['goal']) / get_price(dt['currency'],ex_data) 
        data.set_value(index,'goal',price)
    print('price normalization complete')
    return data

#modification to project name and description
def get_ratio(name):
    sc = 1
    ab = 1
    for c in name:
        if c.isalpha():
            ab += 1
        else:
            sc += 1
    return sc/ab
            

def normalize_name_and_desc(data):
    for index,dt in data.iterrows():
        name_ratio = get_ratio(str(dt['name']))
        desc_ratio = get_ratio(str(dt['desc']))
        data.set_value(index,'name',name_ratio)
        data.set_value(index,'desc',desc_ratio)
    print('name and desc normalization complete')
    return data
    
def normalize_deadline(data):
    for index,dt in data.iterrows():
        deadline = dt['deadline'] - dt['launched_at']
        data.set_value(index,'deadline',deadline)
    print('deadline normalization complete')
    return data
    
def normalize(data,ex_data):
    data = normalize_deadline(data)
    data = normalize_name_and_desc(data)
    data = normalize_price(data,ex_data)
    return data

# %%
'''
work flow : 
 1. Read training data
 2. fix_errors
 3. Read exchange rates json
 4. Get dataframe of exchange rates
 5. Normalize
 
'''
train_data = read_train_data()
print('read train data')
train_data = fix_errors(train_data)
print('errors fixed')
ex_rates = read_exchange_rates_json()
print('read exchange rates json')
ex_rates = get_exchange_rates_dataframe(ex_rates)
print('dataframe is generated from json data')
train_data = normalize(train_data,ex_rates)
# Out:
# read train data
# replaced 'false' with False and 'true' with True
# errors fixed
# read exchange rates json
# dataframe is generated from json data
# deadline normalization complete
# name and desc normalization complete
# price normalization complete

# %%
import numpy as np

# %%
dt = train_data.loc[:,['disable_communication','goal','deadline','name','desc']].as_matrix().astype(float)

# %%
#linear regression

col = 2
day = 60 * 60 * 60 * 24
# converts seconds into days
for i in range(len(dt)):
    dt[i][col] = dt[i][col]/day

# %%
yt = train_data.loc[:,['final_status']].as_matrix().astype(float)

# %%
import tensorflow.contrib.learn as skflow
from sklearn import datasets, metrics

# %%
#training data
#x
inputY = np.array([yt.T[0],(yt.T == 0.).astype(float)[0]]).T
#y
inputX = dt

# %%
inputY
# Out:
# array([[ 1.,  0.],
#        [ 0.,  1.],
#        [ 0.,  1.],
#        ...,
#        [ 1.,  0.],
#        [ 0.,  1.],
#        [ 0.,  1.]])

# %%
inputX
# Out:
# array([[  0.00000000e+00,   2.00000000e+01,   2.72114281e-08,
#           1.66666667e-01,   2.95238095e-01],
#        [  0.00000000e+00,   3.00000000e+02,   5.40825998e-08,
#           1.81818182e-01,   3.23809524e-01],
#        [  0.00000000e+00,   3.00000000e+01,   3.21190230e-08,
#           2.50000000e-01,   2.83168317e+00],
#        ...,
#        [  0.00000000e+00,   3.20000000e+02,   9.64506173e-08,
#           1.87500000e-01,   2.42424242e-01],
#        [  0.00000000e+00,   3.50000000e+04,   9.95336508e-08,
#           2.30769231e-01,   2.56756757e-01],
#        [  0.00000000e+00,   2.50000000e+04,   1.44675926e-07,
#           1.72413793e-01,   2.14285714e-01]])

# %%
learning_rate = 0.000000001
epoch = 500000
display_interval = 10000
sample_size = length

# %%
x_ = tf.placeholder(tf.float32,[None,5],name="x")

weights = tf.Variable(tf.zeros([5,2]))

biases = tf.Variable(tf.zeros([2]))

#predict

predictions = tf.add(tf.matmul(x_,weights),biases)

#activation function

predicted_answer = tf.nn.softmax(predictions)

y_ = tf.placeholder(tf.float32,[None,2],name="y_")

# %%
cost_function = tf.reduce_sum(tf.pow(y_ - predicted_answer,2))/(2*sample_size)

#gradient descent

optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost_function)

# %%
init = tf.global_variables_initializer()
session = tf.Session()
session.run(init)

# %%
for i in range(epoch):
    session.run(optimizer,feed_dict = {x_:inputX,y_:inputY})
    if i % display_interval == 0:
        values = session.run(cost_function,feed_dict = {x_:inputX,y_:inputY})
        print( "Training step:", '%04d' % (i), "cost=", "{:.9f}".format(values))
# Out:
# Training step: 0000 cost= 0.230077952

# %%
values = session.run(cost_function,feed_dict = {x_:inputX,y_:inputY})
print( "Training step:", '%04d' % (i), "cost=", "{:.9f}".format(values))
# Out:
# Training step: 261948 cost= 0.111111172

# %%
print( "Optimization Finished!")
training_cost = session.run(cost_function, feed_dict={x_: inputX, y_: inputY})
print("Training cost=", training_cost, "W=", session.run(weights), "b=", session.run(biases), '\n')
# Out:
# Optimization Finished!
# Training cost= 0.111111 W= [[ -8.80084990e-05   8.80084990e-05]
#  [ -4.76963323e-04   4.77408670e-04]
#  [ -3.28088063e-03   3.28088086e-03]
#  [  3.97891849e-02  -3.97891738e-02]
#  [ -3.77297425e-03   3.77297471e-03]
#  [ -2.77799810e-03   2.77799810e-03]] b= [-0.00594101  0.00594101]

# %%
guess = session.run(predictions, feed_dict={x_: inputX })

# %%
count = 0
for e in guess:
    if e[0] > 0:
        count += 1

# %%
acount = 0

for e in guess:
    if e[0] > 0:
        acount += 1

# %%
print(count,acount)
# Out:
# 37956 37956

# %%
test = pd.read_csv('./test.csv')

# %%
def norm_pr(data,ex_data):
    count = 0
    for index,dt in data.iterrows():
        count += 1
        price = float(dt['goal']) / np.array(get_price(dt['currency'],ex_data))[0]
     
        data.set_value(index,'goal',price)
    print('price normalization complete',count)
    return data
test = norm_pr(test,ex_rates)
# Out:
# price normalization complete 63465

# %%
test = fix_errors(test)
print('errors fixed',test.size/12)
# Out:
# replaced 'false' with False and 'true' with True
# errors fixed 63465.0

# %%
test = normalize_deadline(test)
test = normalize_name_and_desc(test)
# Out:
# deadline normalization complete
# name and desc normalization complete

# %%
test
# Out:
#            project_id       name      desc           goal  \
# 0       kkst917493670   0.222222  0.260417    7000.000000
# 1      kkst1664901914      0.125  0.222222   35000.000000
# 2       kkst925125077   0.184211  0.242718   49500.000000
# 3      kkst1427645275        0.2  0.195652   40000.000000
# 4      kkst1714249266   0.176471  0.218182   20000.000000
# 5       kkst994744324       0.22   0.23301   10000.000000
# 6       kkst366471810   0.413793  0.209524    1250.635260
# 7      kkst1686645245   0.333333  0.333333     486.587192
# 8      kkst1009612119      0.125  0.212121    6000.000000
# 9       kkst774947236   0.234043  0.244681    8000.000000
# 10      kkst751736613    39.6154   5.02804   25000.000000
# 11      kkst546487059   0.277778      0.25   12000.000000
# 12      kkst184185617   0.363636  0.266667    5000.000000
# 13       kkst14737712   0.230769  0.233766    6300.000000
# 14     kkst1709731255   0.264706  0.236842   50000.000000
# 15      kkst677310901   0.133333  0.231481    7136.612144
# 16     kkst2017864312   0.181818  0.323529   50000.000000
# 17      kkst263053778   0.210526  0.235294    3243.914611
# 18      kkst515365696   0.153846  0.216216    9731.743832
# 19     kkst1399418181   0.263158   4.91743    3751.905781
# 20     kkst1923573285        0.2  0.252336   20000.000000
# 21     kkst1835523556  0.0909091  0.196429    5551.959856
# 22      kkst691313362    0.25641  0.283784    5000.000000
# 23     kkst1801490632   0.222222  0.321429   12000.000000
# 24     kkst1370169828        0.2   0.19802    2873.086616
# 25       kkst69680953   0.142857  0.207547    4054.893264
# 26       kkst65991350       0.15   0.20202    5676.850569
# 27      kkst533894809   0.176471  0.220183   16500.000000
# 28     kkst1416439353       0.25  0.223214   50000.000000
# 29     kkst1728612166   0.235294      0.31   24329.359581
# ...               ...        ...       ...            ...
# 63435  kkst2098627341   0.393939  0.319149    9000.000000
# 63436  kkst1803681768   0.169811      0.22  100000.000000
# 63437  kkst1944372205       0.25  0.328125     756.561278
# 63438   kkst175165058   0.195122  0.247312    3354.954149
# 63439  kkst1206847840   0.233333  0.266667    6822.316555
# 63440  kkst2053271225   0.227273  0.175439   13000.000000
# 63441  kkst1170363987   0.209302   0.23301    1822.024634
# 63442  kkst1872082968        0.5  0.257143    6000.000000
# 63443   kkst868147124   0.318182  0.240385    7000.000000
# 63444    kkst96793268   0.341463  0.245098    7000.000000
# 63445   kkst233040768   0.444444  0.240506    5500.000000
# 63446   kkst192706265   0.222222  0.188889    5285.277636
# 63447  kkst1648941684     0.1875  0.256881   27000.000000
# 63448   kkst454855107   0.333333   0.25641     303.214069
# 63449  kkst1847337196   0.318182  0.282828   11630.507716
# 63450  kkst1970590230    0.26087  0.245283    9000.000000
# 63451  kkst1997992565   0.261905  0.236559    5000.000000
# 63452   kkst151500671   0.173913  0.245455    2500.000000
# 63453  kkst1852942336   0.181818  0.207207    1800.000000
# 63454   kkst193556602   0.181818  0.346535    2547.121752
# 63455  kkst2101292403   0.190476   0.27619    2500.000000
# 63456  kkst1986637168   0.176471  0.227273   76413.652573
# 63457   kkst601559396   0.212766  0.206897    2550.834487
# 63458  kkst1220292885   0.347826  0.284314    4444.000000
# 63459  kkst1908033896    11.3913  0.287129    2000.000000
# 63460   kkst538121766   0.185185  0.259615    6000.000000
# 63461  kkst1927608005   0.238095  0.264151    1500.000000
# 63462    kkst68821321   0.215686  0.190909    3026.245111
# 63463   kkst665771257   0.285714  0.301075   42800.000000
# 63464  kkst1164902454   0.216216  0.256881     850.000000
#
#                                                 keywords  \
# 0                                               brathair
# 1                                       the-screenwriter
# 2            the-hornets-nest-the-fairmont-heights-story
# 3      brothers-season-2-groundbreaking-transgender-male
# 4                                     blackdom-the-movie
# 5                                 heros-battle-the-movie
# 6                  limbo-film-project-213-lives-of-julia
# 7                                   traffic-a-short-film
# 8                                       modern-gangsters
# 9        kiss-me-goodbye-a-new-voice-in-indie-filmmaking
# 10                                        a-brighter-day
# 11                                  like-son-like-father
# 12     pre-production-the-heart-of-a-woman-and-the-heart
# 13          the-ecstasy-of-vengeance-feature-length-film
# 14                                           hart-blvd-0
# 15                                       invisible-scars
# 16                                           true-colors
# 17                                 trial-and-error-movie
# 18                                       the-messenger-1
# 19          la-notte-di-sangue-pulp-western-feature-film
# 20                                            bravo-team
# 21                                            immemorial
# 22     the-imbalanced-heart-of-a-symmetric-mind-featu...
# 23                                 regionrat-the-movie-0
# 24                                 trillion-feature-film
# 25                                desperation-short-film
# 26                                 thunder-under-control
# 27                ndolo-and-the-senator-houston-premiere
# 28                      connections-part-2-final-affairs
# 29                the-escort-an-independent-feature-film
# ...                                                  ...
# 63435           muzz-do-you-know-where-the-anti-venom-is
# 63436  bangarang-books-augmented-and-virtual-reality-...
# 63437                                           sand-dog
# 63438  librodime-your-first-really-personalized-child...
# 63439                jet-black-publishing-launch-phase-1
# 63440  my-dad-is-a-heating-and-air-conditioning-techn...
# 63441  re-printing-3-ancient-samoan-stories-for-chris...
# 63442                                oh-my-gosh-its-josh
# 63443                          btwd-before-there-was-day
# 63444  the-adventures-of-bugaboo-and-ladybug-up-up-an...
# 63445                                         are-you-it
# 63446                               the-prince-of-hounds
# 63447                                  sneaky-meat-treat
# 63448                                     pig-in-the-wig
# 63449  salvi-and-maya-childrens-books-small-books-big...
# 63450  the-purple-teddy-bear-childrens-book-seeking-t...
# 63451    kids-reality-books-blending-fiction-and-reality
# 63452                          the-benjamin-carson-story
# 63453                            georgethe-alaskan-eagle
# 63454                           how-to-draw-kookydoodles
# 63455                            amazing-smells-of-paris
# 63456                                 kitty-wizard-world
# 63457  jack-and-the-fish-eating-dragon-picture-and-po...
# 63458                       strong-as-lion-big-as-a-tree
# 63459  angelinas-concertina-plays-again-the-power-of-...
# 63460                     singing-whales-and-other-tales
# 63461                           the-dragon-of-wawel-hill
# 63462  someone-you-love-has-cancer-a-childs-guide-to-...
# 63463                                    a-germs-journey
# 63464           daisys-sensory-adventures-childrens-book
#
#        disable_communication country currency  deadline  state_changed_at  \
# 0                      False      US      USD   3459600        1449619185
# 1                      False      US      USD   3024000        1453435620
# 2                      False      US      USD   3108572        1451780700
# 3                      False      US      USD   2592000        1445021530
# 4                      False      US      USD   3733950        1462068844
# 5                      False      US      USD   2592000        1461777994
# 6                      False      IT      EUR   2592000        1450087423
# 7                      False      GB      GBP   5176616        1456516801
# 8                      False      US      USD   2587376        1444337941
# 9                      False      US      USD   3024000        1444144223
# 10                     False      US      USD   2592000        1436566136
# 11                     False      US      USD   2518008        1443675613
# 12                     False      US      USD   2592000        1442634617
# 13                     False      US      USD   5180400        1460837320
# 14                     False      US      USD   2591454        1439734002
# 15                     False      GB      GBP   3695258        1455753540
# 16                     False      US      USD   2761715        1459493941
# 17                     False      GB      GBP   5180400        1458917849
# 18                     False      GB      GBP   2592000        1460637604
# 19                     False      IT      EUR   2592000        1446156259
# 20                     False      US      USD   2496957        1444342020
# 21                     False      GB      GBP   2592000        1434995298
# 22                     False      US      USD   2078483        1437461941
# 23                     False      US      USD    864000        1466091448
# 24                     False      AU      AUD   3456000        1443782138
# 25                     False      GB      GBP   5184000        1457308532
# 26                     False      GB      GBP   2447902        1444510814
# 27                     False      US      USD    604800        1453877073
# 28                     False      US      USD   2674262        1436721660
# 29                     False      GB      GBP   2588400        1458466404
# ...                      ...     ...      ...       ...               ...
# 63435                  False      US      USD   2589253        1465957502
# 63436                  False      US      USD   2422800        1479592052
# 63437                  False      CA      CAD   3027600        1448088095
# 63438                  False      IT      EUR   3456000        1450123532
# 63439                  False      AU      AUD   2592000        1442039326
# 63440                  False      US      USD   2588400        1490321152
# 63441                  False      NZ      NZD   2595600        1447809446
# 63442                  False      US      USD   2592000        1438908726
# 63443                  False      US      USD   2592000        1484443453
# 63444                  False      US      USD   5184000        1473108353
# 63445                  False      US      USD   5187600        1482092160
# 63446                  False      GB      GBP   2592000        1446289232
# 63447                  False      US      USD   5187600        1446426318
# 63448                  False      AU      AUD    604800        1484341995
# 63449                  False      NL      EUR   2073600        1441989212
# 63450                  False      US      USD   2795434        1435726742
# 63451                  False      US      USD   1209600        1434409083
# 63452                  False      US      USD   3486682        1451624340
# 63453                  False      US      USD   2592000        1434817532
# 63454                  False      GB      GBP   2592000        1457563865
# 63455                  False      US      USD   2592000        1473373531
# 63456                  False      GB      GBP   5184000        1452804805
# 63457                  False      NZ      NZD   1728000        1480249076
# 63458                  False      US      USD   2592000        1449679245
# 63459                  False      US      USD   5183709        1469926740
# 63460                  False      US      USD   4599807        1435716012
# 63461                  False      US      USD   3888000        1445852908
# 63462                  False      CA      CAD   3193741        1464795540
# 63463                  False      US      USD   5184000        1465663810
# 63464                  False      US      USD   1296000        1441604548
#
#        created_at  launched_at
# 0      1446002581   1446159585
# 1      1450297323   1450411620
# 2      1448581356   1448672128
# 3      1440966830   1442429518
# 4      1455765276   1458334890
# 5      1458171626   1459185994
# 6      1446994619   1447495423
# 7      1450964837   1451340184
# 8      1441745957   1441750564
# 9      1438886415   1441120222
# 10     1433754939   1433974135
# 11     1441080577   1441157592
# 12     1440026384   1440042617
# 13     1455503889   1455656920
# 14     1436884427   1437142547
# 15     1451927214   1452058282
# 16     1409004090   1456732225
# 17     1453455955   1453737449
# 18     1451404406   1458045604
# 19     1441649385   1443564257
# 20     1440348699   1441845063
# 21     1430570028   1432403295
# 22     1434646137   1435383457
# 23     1465184057   1465227446
# 24     1440318289   1440326138
# 25     1452041873   1452124531
# 26     1441462978   1442062898
# 27     1453258389   1453272273
# 28     1434043284   1434047398
# 29     1454767309   1455878004
# ...           ...          ...
# 63435  1462415963   1463368247
# 63436  1476707331   1477169252
# 63437  1444965317   1445060495
# 63438  1446063469   1446667532
# 63439  1438667203   1439447326
# 63440  1485885198   1487732751
# 63441  1443894181   1445213846
# 63442  1436313014   1436316726
# 63443  1481782586   1481851452
# 63444  1467855881   1467924353
# 63445  1476313227   1476904558
# 63446  1440602305   1443697232
# 63447  1441234023   1441238718
# 63448  1483137856   1483737195
# 63449  1427293512   1439915612
# 63450  1430445428   1432931306
# 63451  1432746400   1433199482
# 63452  1447724171   1448137658
# 63453  1429325876   1432225531
# 63454  1454803785   1454971864
# 63455  1466793790   1470781531
# 63456  1447184092   1447620803
# 63457  1477989860   1478521075
# 63458  1446926489   1447087245
# 63459  1397438267   1464743031
# 63460  1428711315   1431116193
# 63461  1441329321   1441964907
# 63462  1461598078   1461601799
# 63463  1459271498   1460479810
# 63464  1440303093   1440308548
#
# [63465 rows x 12 columns]
